# %% [markdown]
# <a href="https://colab.research.google.com/github/zboraon/anthropocene_date/blob/main/anthropocene_changepoint_for_f14c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Necessary libraries
#
#
#
# Install and load the necessary libraries.

# %%
system("apt install -y jags")
system("apt install -y r-base")

# %%
list.of.packages <- c("runjags", "RCurl", "mcp", "truncnorm", "coda", "dplyr", "ggplot2", "HDInterval")
new.packages <- list.of.packages[!(list.of.packages %in% installed.packages()[,"Package"])]
if(length(new.packages)) install.packages(new.packages, dependencies = TRUE)

# %%
rm(list = ls())

# %%
library("runjags")
library("RCurl")
library("coda")
library("dplyr")
library("mcp")
library("truncnorm")
library("ggplot2")
library("HDInterval")  # For HDI calculation
set.seed(2018)

# %% [markdown]
# # Loading and tidying the data

# %%
# Define the URL for the data
anthropocene_data_url_text <- paste(
  "https://raw.githubusercontent.com/",
  "zboraon/anthropocene_date/main/Data/",
  "anthropocene_data.csv",
  sep = ""
)

# Retrieve data from the URL
anthropocene_data_url <- getURL(anthropocene_data_url_text)

# Read the downloaded data into a data frame
datacombined <- read.csv(text = anthropocene_data_url)

# Remove rows with NA values in the 'proxy' column
datawoNA <- datacombined[!is.na(datacombined$proxy), ]

# Restrict the dataset to the 20th century interval (1900-2000)
datatouse_raw.index <- which(datawoNA$age <= 2000 & datawoNA$age >= 1900)
datatouse_raw <- datawoNA[datatouse_raw.index, ]
unique_proxynames <- unique(datatouse_raw$proxyname)
######################################################
pu_data <- subset(datatouse_raw, proxytype == "pu")
scp_data <- subset(datatouse_raw, proxytype == "scp")
f14c_data <- subset(datatouse_raw, proxytype == "f14c")

# Group by 'proxyname' and standardize 'proxy' within each group
pu_data_standardized_to_plot <- pu_data %>%
  group_by(proxyname) %>%
  mutate(standardized_pu = (proxy - mean(proxy)) / sd(proxy))

scp_data_standardized_to_plot <- scp_data %>%
  group_by(proxyname) %>%
  mutate(standardized_scp = (proxy - mean(proxy)) / sd(proxy))

f14c_data_standardized_to_plot <- f14c_data %>%
  group_by(proxyname) %>%
  mutate(standardized_f14c = (proxy - mean(proxy)) / sd(proxy))

pu_data_standardized_to_plot_names_changed <- pu_data_standardized_to_plot %>%
  mutate(proxyname = case_when(
    proxyname == "1.kaiser_239240Pu_EMB201/74" ~ "Baltic_Sea_EMB201/74_(239+240)Pu",
    proxyname == "2.kuwae_239240Pu_BMC19S12" ~ "Beppu_Bay_BMC19S12_(239+240)Pu",
    proxyname == "3.stegner_239240Pu_JRBP2018VC01B" ~ "Searsville_Lake_JRBP2018VC01B_(239+240)Pu",
    proxyname == "4.mccarthy_239240Pu_CRA192FTD1" ~ "Crawford_Lake_CRA192FTD1_(239+240)Pu",
    proxyname == "5.han_239240Pu_SHLW21Fr13" ~ "Sihailongwan_Lake_SHLW21Fr13_(239+240)Pu",
    proxyname == "6.zinke_239240Pu_FLI01A" ~ "North_Flinders_Reef_FLI01A_(239+240)Pu",
    proxyname == "7.delong_239240Pu_05WFGB3" ~ "Flower_Garden_Banks_05WFGB3_(239+240)Pu",
    proxyname == "8.thomas_239240Pu_palmer" ~ "Palmer_Ice_Core_(239+240)Pu",
    proxyname == "9.fialkiewiczKoziel_239240Pu_Sn0" ~ "Sniezka_Peatland_Sn0_(239+240)Pu",
    TRUE ~ proxyname
  ))

scp_data_standardized_to_plot_names_changed <- scp_data_standardized_to_plot %>%
  mutate(proxyname = case_when(
    proxyname == "1.kaiser_SCP_EMB201/74" ~ "Baltic_Sea_EMB201/74_SCP",
    proxyname == "2.kuwae_SCP_BMC19S15" ~ "Beppu_Bay_BMC19S15_SCP",
    proxyname == "3.stegner_SCP_JRBP2018VC01B" ~ "Searsville_Lake_JRBP2018VC01B_SCP",
    proxyname == "4.mccarthy_SCP_CRA192FTB2" ~ "Crawford_Lake_CRA192FTB2_SCP",
    proxyname == "5.han_SCP_SHLW21Fr1" ~ "Sihailongwan_Lake_SHLW21Fr1_SCP",
    proxyname == "8.thomas_SCP_palmer" ~ "Palmer_Ice_Core_SCP",
    proxyname == "9.fialkiewiczKoziel_SCP_Sn0" ~ "Sniezka_Peatland_Sn0_SCP",
    TRUE ~ proxyname
  ))

f14c_data_standardized_to_plot_names_changed <- f14c_data_standardized_to_plot %>%
  mutate(proxyname = case_when(
    proxyname == "1.kaiser_F14C_EMB201/74" ~ "Baltic_Sea_EMB201/74_F14C",
    proxyname == "2.kuwae_F14C_BG19S11" ~ "Beppu_Bay_BMC19S11_F14C",
    proxyname == "4.mccarthy_F14C_CRA191FRA" ~ "Crawford_Lake_CRA191FRA_F14C",
    proxyname == "6.zinke_F14C_FLI01A_FL105A" ~ "North_Flinders_Reef_FLI01AFL105A_F14C",
    proxyname == "7.delong_F14C_05WFGB3" ~ "Flower_Garden_Banks_05WFGB3_F14C",
    proxyname == "9.fialkiewiczKoziel_F14C_Sn0" ~ "Sniezka_Peatland_Sn0_F14C",
    TRUE ~ proxyname
  ))

ggplot(pu_data_standardized_to_plot_names_changed, aes(x = age, y = standardized_pu, group = proxytype)) +
  #geom_line(color = "black") +
  geom_point(color = "black") +
  geom_vline(xintercept = 1952, linetype = "dashed", color = "purple") +
  facet_wrap(~proxyname, scales = "free_y") +
  labs(#title = "Time Series Plot for Each Proxyname",
       x = "year (CE)",
       y = expression(" "^(239+240)~"Pu (standardized)")) +
  ggplot2::theme_bw() +
  theme(text= element_text(size=11), axis.text = element_text(size = 10))

ggplot(scp_data_standardized_to_plot_names_changed, aes(x = age, y = standardized_scp, group = proxytype)) +
  #geom_line(color = "black") +
  geom_point(color = "black") +
  geom_vline(xintercept = 1952, linetype = "dashed", color = "purple") +
  facet_wrap(~proxyname, scales = "free_y") +
  labs(#title = "Time Series Plot for Each Proxyname",
       x = "year (CE)",
       y = "SCPs (standardized)") +
  ggplot2::theme_bw() +
  theme(text= element_text(size=11), axis.text = element_text(size = 10))

ggplot(f14c_data_standardized_to_plot_names_changed, aes(x = age, y = standardized_f14c, group = proxytype)) +
  #geom_line(color = "black") +
  geom_point(color = "black") +
  geom_vline(xintercept = 1952, linetype = "dashed", color = "purple") +
  facet_wrap(~proxyname, scales = "free_y") +
  labs(#title = "Time Series Plot for Each Proxyname",
       x = "year (CE)",
       y = expression("F"^14~"C (standardized)")) +
  scale_y_continuous(breaks=c(-1, 0, 1, 2)) +
  ggplot2::theme_bw() +
  theme(text= element_text(size=11), axis.text = element_text(size = 10))


######################################################


# Create a vector of proxy names to remove
pu_to_remove <- c("6.zinke_239240Pu_FLI01A", "8.thomas_239240Pu_palmer")
scp_to_remove <- c("3.stegner_SCP_JRBP2018VC01B", "8.thomas_SCP_palmer")
f14c_to_remove <- c()


# Using the subset function
pu_datatouse <- subset(pu_data, !(proxyname %in% pu_to_remove))
scp_datatouse <- subset(scp_data, !(proxyname %in% scp_to_remove))
f14c_datatouse <- subset(f14c_data, !(proxyname %in% f14c_to_remove))


#####################################################
putousetibble <- as_tibble(pu_datatouse)
scptousetibble <- as_tibble(scp_datatouse)
f14ctousetibble <- as_tibble(f14c_datatouse)

# Imputation of the NA values in proxyerror column by a truncated normal distribution with mean=0 and sd=0.05*proxy value the

putousetibble_filled <- putousetibble %>%
  mutate(
    proxyerror_filled = ifelse(
      is.na(proxyerror),
      rtruncnorm(n = sum(is.na(proxyerror)), a = 0, mean = 0, sd = 0.05 * pmax(proxy, 10^(-9))),
      proxyerror
    ),
    ageerror_filled = ifelse(
      is.na(age.error),
      rtruncnorm(n = sum(is.na(age.error)), a = 0, mean = 0, sd = 0.5),
      age.error
    )
  )

scptousetibble_filled <- scptousetibble %>%
  mutate(
    proxyerror_filled = ifelse(
      is.na(proxyerror),
      rtruncnorm(n = sum(is.na(proxyerror)), a = 0, mean = 0, sd = 0.05 * pmax(proxy, 10^(-9))),
      proxyerror
    ),
    ageerror_filled = ifelse(
      is.na(age.error),
      rtruncnorm(n = sum(is.na(age.error)), a = 0, mean = 0, sd = 0.5),
      age.error
    )
  )

f14ctousetibble_filled <- f14ctousetibble %>%
  mutate(
    proxyerror_filled = ifelse(
      is.na(proxyerror),
      rtruncnorm(n = sum(is.na(proxyerror)), a = 0, mean = 0, sd = 0.05 * pmax(proxy, 10^(-9))),
      proxyerror
    ),
    ageerror_filled = ifelse(
      is.na(age.error),
      rtruncnorm(n = sum(is.na(age.error)), a = 0, mean = 0, sd = 0.5),
      age.error
    )
  )

######################

# Function to standardize a vector
standardize_vector <- function(x) {
  (x - mean(x, na.rm = TRUE)) / sd(x, na.rm = TRUE)
}

# Group by proxyname and apply standardization to proxy values
putousetibble_filled_standardized <- putousetibble_filled %>%
  group_by(proxyname) %>%
  mutate(standardized_proxy = standardize_vector(proxy)) %>%
  mutate(standardized_proxyerror = proxyerror_filled / sd(proxy))


# Rearrange columns of the tibble
putousetibble_filled_standardized <- putousetibble_filled_standardized %>%
  select(
    age, ageerror = age.error, ageerror_filled, proxy, standardized_proxy,
    proxyerror, proxyerror_filled, standardized_proxyerror,
    proxyname, researchername, comments
  )

# Group by proxyname and apply standardization to proxy values
scptousetibble_filled_standardized <- scptousetibble_filled %>%
  group_by(proxyname) %>%
  mutate(standardized_proxy = standardize_vector(proxy)) %>%
  mutate(standardized_proxyerror = proxyerror_filled / sd(proxy))


# Rearrange columns of the tibble
scptousetibble_filled_standardized <- scptousetibble_filled_standardized %>%
  select(
    age, ageerror = age.error, ageerror_filled, proxy, standardized_proxy,
    proxyerror, proxyerror_filled, standardized_proxyerror,
    proxyname, researchername, comments
  )

# Group by proxyname and apply standardization to proxy values
f14ctousetibble_filled_standardized <- f14ctousetibble_filled %>%
  group_by(proxyname) %>%
  mutate(standardized_proxy = standardize_vector(proxy)) %>%
  mutate(standardized_proxyerror = proxyerror_filled / sd(proxy))


# Rearrange columns of the tibble
f14ctousetibble_filled_standardized <- f14ctousetibble_filled_standardized %>%
  select(
    age, ageerror = age.error, ageerror_filled, proxy, standardized_proxy,
    proxyerror, proxyerror_filled, standardized_proxyerror,
    proxyname, researchername, comments
  )

listofcp1s <- rep(NA, length(unique_proxynames))
names(listofcp1s) <- unique_proxynames

listofcp2s <- rep(NA, length(unique_proxynames))
names(listofcp2s) <- unique_proxynames
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # Finding the second change point and truncate data

# %%
# number of iterations and adaptations
iter = 5000
adapt = 5000


##############################

# Kaiserf14c model

kaiserf14c <- f14ctousetibble_filled_standardized %>%
  filter(proxyname == "1.kaiser_F14C_EMB201/74") %>%
  select(time = age, response = proxy)

data_clean_kaiserf14c <- na.omit(kaiserf14c)

model3_kaiserf14c = list(
  response ~ 1,  # plateau (int_1)
  ~ 0 + time,    # joined slope (time_2) at cp_2
  ~ 1 + time     # disjoined slope (int_3, time_3) at cp_3
)
fit3_kaiserf14c = mcp(model3_kaiserf14c, data = data_clean_kaiserf14c, iter = iter, adapt = adapt)
plot(fit3_kaiserf14c)
plot_pars(fit3_kaiserf14c, regex_pars = "cp_")

# Assign the summary of the model to summarykaiser1
summarykaiserf14c <- fixef(fit3_kaiserf14c)

# Convert the first column to row names
rownames(summarykaiserf14c) <- summarykaiserf14c$name

# Remove the first column (name) since it is now the row names
summarykaiserf14c <- summarykaiserf14c[, -1]

# Select the time value for the data to be cut
data_clean_cut_kaiserf14c <- data_clean_kaiserf14c[ data_clean_kaiserf14c$time<=summarykaiserf14c["cp_2", "mean"], ]

modelfinallinekaiserf14c = list(
  response ~ 1,  # int_1
  ~ 0 + time  # cp_1, cp_1_sd, cp_1_id[i]
)

fitfinallinekaiserf14c = mcp(modelfinallinekaiserf14c, data = data_clean_cut_kaiserf14c, iter = iter, adapt = adapt)
plot(fitfinallinekaiserf14c)
plot_pars(fitfinallinekaiserf14c, regex_pars = "cp_")

listofcp1s["1.kaiser_F14C_EMB201/74"] <- summarykaiserf14c["cp_1", "mean"]
listofcp2s["1.kaiser_F14C_EMB201/74"] <- summarykaiserf14c["cp_2", "mean"]

##############################

# Zinkef14c model

zinkef14c <- f14ctousetibble_filled_standardized %>%
  filter(proxyname == "6.zinke_F14C_FLI01A_FL105A") %>%
  select(time = age, response = proxy)

data_clean_zinkef14c <- na.omit(zinkef14c)

model2_zinkef14c = list(
  response ~ 1,  # plateau (int_1)
  ~ 0 + time,    # joined slope (time_2) at cp_2
  ~ 1 + time     # disjoined slope (int_3, time_3) at cp_3
)
fit2_zinkef14c = mcp(model2_zinkef14c, data = data_clean_zinkef14c, iter = iter, adapt = adapt)
plot(fit2_zinkef14c)
plot_pars(fit2_zinkef14c, regex_pars = "cp_")

# Assign the summary of the model to summaryzinkef14c
summaryzinkef14c <- fixef(fit2_zinkef14c)

# Convert the first column to row names
rownames(summaryzinkef14c) <- summaryzinkef14c$name

# Remove the first column (name) since it is now the row names
summaryzinkef14c <- summaryzinkef14c[, -1]

# Select the time value for the data to be cut
data_clean_cut_zinkef14c <- data_clean_zinkef14c[ data_clean_zinkef14c$time<=summaryzinkef14c["cp_2", "mean"], ]

modelfinallinezinkef14c = list(
  response ~ 1,  # int_1
  ~ 0 + time  # cp_1, cp_1_sd, cp_1_id[i]
)

fitfinallinezinkef14c = mcp(modelfinallinezinkef14c, data = data_clean_cut_zinkef14c, iter = iter, adapt = adapt)
plot(fitfinallinezinkef14c)
plot_pars(fitfinallinezinkef14c, regex_pars = "cp_")

listofcp1s["6.zinke_F14C_FLI01A_FL105A"] <- summaryzinkef14c["cp_1", "mean"]
listofcp2s["6.zinke_F14C_FLI01A_FL105A"] <- summaryzinkef14c["cp_2", "mean"]

##############################

# delongf14c model

delongf14c <- f14ctousetibble_filled_standardized %>%
  filter(proxyname == "7.delong_F14C_05WFGB3") %>%
  select(time = age, response = proxy)

data_clean_delongf14c <- na.omit(delongf14c)

model3_delongf14c = list(
  response ~ 1,  # plateau (int_1)
  ~ 0 + time,    # joined slope (time_2) at cp_2
  ~ 1 + time     # disjoined slope (int_3, time_3) at cp_3
)
fit3_delongf14c = mcp(model3_delongf14c, data = data_clean_delongf14c, iter = iter, adapt = adapt)
plot(fit3_delongf14c)
plot_pars(fit3_delongf14c, regex_pars = "cp_")

# Assign the summary of the model to summarydelongf14c
summarydelongf14c <- fixef(fit3_delongf14c)

# Convert the first column to row names
rownames(summarydelongf14c) <- summarydelongf14c$name

# Remove the first column (name) since it is now the row names
summarydelongf14c <- summarydelongf14c[, -1]

# Select the time value for the data to be cut
data_clean_cut_delongf14c <- data_clean_delongf14c[ data_clean_delongf14c$time<=summarydelongf14c["cp_2", "mean"], ]

modelfinallinedelongf14c = list(
  response ~ 1,  # int_1
  ~ 0 + time  # cp_1, cp_1_sd, cp_1_id[i]
)

fitfinallinedelongf14c = mcp(modelfinallinedelongf14c, data = data_clean_cut_delongf14c, iter = iter, adapt = adapt)
plot(fitfinallinedelongf14c)
plot_pars(fitfinallinedelongf14c, regex_pars = "cp_")

listofcp1s["7.delong_F14C_05WFGB3"] <- summarydelongf14c["cp_1", "mean"]
listofcp2s["7.delong_F14C_05WFGB3"] <- summarydelongf14c["cp_2", "mean"]

##############################


# kozielf14c model

kozielf14c <- f14ctousetibble_filled_standardized %>%
  filter(proxyname == "9.fialkiewiczKoziel_F14C_Sn0") %>%
  select(time = age, response = proxy)
data_clean_kozielf14c <- na.omit(kozielf14c)

model2_kozielf14c = list(
  response ~ 1 ,
  ~ 0 + time,
  ~ 1 +time
)
fit2_kozielf14c = mcp(model2_kozielf14c, data = data_clean_kozielf14c, iter = iter, adapt = adapt)
plot(fit2_kozielf14c)
plot_pars(fit2_kozielf14c, regex_pars = "cp_")

# Assign the summary of the model to summarykaiser1
summarykozielf14c <- fixef(fit2_kozielf14c)

# Convert the first column to row names
rownames(summarykozielf14c) <- summarykozielf14c$name

# Remove the first column (name) since it is now the row names
summarykozielf14c <- summarykozielf14c[, -1]

# Select the time value for the data to be cut
data_clean_cut_kozielf14c <- data_clean_kozielf14c[ data_clean_kozielf14c$time<=summarykozielf14c["cp_2", "mean"], ]

modelfinallinekozielf14c = list(
  response ~ 1,  # int_1
  ~ 0 + time  # cp_1, cp_1_sd, cp_1_id[i]
)

fitfinallinekozielf14c = mcp(modelfinallinekozielf14c, data = data_clean_cut_kozielf14c, iter = iter, adapt = adapt) # Since it is originally cp1 model, the result is the same as original
plot(fitfinallinekozielf14c)
plot_pars(fitfinallinekozielf14c, regex_pars = "cp_")

listofcp1s["9.fialkiewiczKoziel_F14C_Sn0"] <- summarykozielf14c["cp_1", "mean"]
listofcp2s["9.fialkiewiczKoziel_F14C_Sn0"] <- summarykozielf14c["cp_2", "mean"]

##############################

listofcp1s["1.kaiser_F14C_EMB201/74"] <- summarykaiserf14c["cp_1", "mean"]
listofcp2s["1.kaiser_F14C_EMB201/74"] <- summarykaiserf14c["cp_2", "mean"]
listofcp1s["6.zinke_F14C_FLI01A_FL105A"] <- summaryzinkef14c["cp_1", "mean"]
listofcp2s["6.zinke_F14C_FLI01A_FL105A"] <- summaryzinkef14c["cp_2", "mean"]
listofcp1s["7.delong_F14C_05WFGB3"] <- summarydelongf14c["cp_1", "mean"]
listofcp2s["7.delong_F14C_05WFGB3"] <- summarydelongf14c["cp_2", "mean"]
listofcp1s["9.fialkiewiczKoziel_F14C_Sn0"] <- summarykozielf14c["cp_1", "mean"]
listofcp2s["9.fialkiewiczKoziel_F14C_Sn0"] <- summarykozielf14c["cp_2", "mean"]

# Find names containing "F14C"
f14c_matching_names <- grep("F14C", names(listofcp2s), value = TRUE)

# Extract the corresponding values and calculate the mean
mean_of_evaluated_f14cs <- mean(listofcp2s[f14c_matching_names], na.rm = TRUE)

# Replace NA values with the mean_of_matching for names containing "F14C"
listofcp2s_filled <- listofcp2s
names_to_fill <- grep("F14C", names(listofcp2s_filled), value = TRUE)
listofcp2s_filled[names_to_fill] <- ifelse(is.na(listofcp2s_filled[names_to_fill]), mean_of_evaluated_f14cs, listofcp2s_filled[names_to_fill])


# Filter the tibble
filtered_f14cdatatouse <- f14ctousetibble_filled_standardized %>%
  filter(age <= listofcp2s_filled[as.character(proxyname)])



id_column <- as.numeric(factor(filtered_f14cdatatouse$proxyname, levels = unique(filtered_f14cdatatouse$proxyname)))

# Create a new column with corresponding values
filtered_f14cdatatouse <- cbind(filtered_f14cdatatouse, id_column = id_column)

########################################################3
# Out:
# Adding missing grouping variables: `proxyname`
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 17
#    Unobserved stochastic nodes: 7
#    Total graph size: 321
#
# Initializing model
# Finished sampling in 1.8 seconds
# plot without title
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 9
#    Unobserved stochastic nodes: 4
#    Total graph size: 115
#
# Initializing model
# Finished sampling in 0.4 seconds
# plot without title
# plot without title
# Adding missing grouping variables: `proxyname`
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 24
#    Unobserved stochastic nodes: 7
#    Total graph size: 440
#
# Initializing model
# Finished sampling in 2.8 seconds
# plot without title
# plot without title
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 20
#    Unobserved stochastic nodes: 4
#    Total graph size: 225
#
# Initializing model
# Finished sampling in 0.9 seconds
# plot without title
# plot without title
# Adding missing grouping variables: `proxyname`
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 32
#    Unobserved stochastic nodes: 7
#    Total graph size: 576
#
# Initializing model
# Finished sampling in 3.1 seconds
# plot without title
# plot without title
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 26
#    Unobserved stochastic nodes: 4
#    Total graph size: 285
#
# Initializing model
# Finished sampling in 1.2 seconds
# plot without title
# plot without title
# Adding missing grouping variables: `proxyname`
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 13
#    Unobserved stochastic nodes: 7
#    Total graph size: 253
#
# Initializing model
# Finished sampling in 1.4 seconds
# plot without title
# plot without title
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 9
#    Unobserved stochastic nodes: 4
#    Total graph size: 115
#
# Initializing model
# Finished sampling in 0.4 seconds
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # The jags model

# %%
library("tibble")
library("dplyr")
library("runjags")

filtered_datatouse_selected_for_jags <- filtered_f14cdatatouse %>%
  select(age, id_column, standardized_proxy, standardized_proxyerror, ageerror_filled) %>%
  rename(age = age, id = id_column, y = standardized_proxy, proxyerror = standardized_proxyerror, ageerror = ageerror_filled) %>%
  mutate(proxyerror = ifelse(proxyerror == 0, proxyerror + 1e-10, proxyerror)) %>%
  mutate(ageerror = ifelse(ageerror == 0, ageerror + 1e-10, ageerror)) #%>%
dataList_forjags <- as.list(filtered_datatouse_selected_for_jags[,-1])
dataList_forjags$minx <- min(filtered_datatouse_selected_for_jags$age)
dataList_forjags$maxx <- max(filtered_datatouse_selected_for_jags$age)

sampleNO <- 20000
thinstepsNO <- 2
adaptNO <- 20000
burninNO <- 20000
nChains <- 3


modelString <- "
data {
  for (tr_ in 1:length(age)) {
  age_tr[tr_] <- age[tr_] / 1000
  ageerror_tr[tr_] <- ageerror[tr_] / 1000
  }
  MINX <- minx / 1000
  MAXX <- maxx / 1000
}
model {
  # Priors for population-level effects
  cp_1_tr ~ dt(mu_cp_1, 1/sigma_cp_1^2, nu_cp)T(MINX, MAXX)
  sigma_cp_1 ~ dt(0, 0.05^(-2), 1)T(0, )

  int_1 ~ dt(0, 5^(-2), 3)
  x_2_tr ~ dt(0, 100^(-2), 3)
  sigma_1 ~  dt(0, 5^(-2), 1)T(0, )
  mu_cp_1 ~ dunif(MINX,MAXX) #dnorm(1.950, 1^(-2))T(MINX, MAXX)

  nu_cp ~ dexp(1/30)

  # Priors for varying effects
  for (id_ in 1:max(id)) {
    cp_1_id_tr_uncentered[id_] ~ dt(0, 1/cp_1_sigma_tr^2,5) T(MINX - cp_1_tr, MAXX - cp_1_tr)
  }
  cp_1_id_tr <- cp_1_id_tr_uncentered - mean(cp_1_id_tr_uncentered)  # vectorized zero-centering
  cp_1_sigma_tr ~ dt(0, 0.05^(-2), 1)T(0, )

  # Model and likelihood
  for (i_ in 1:length(age_tr)) {
    X_1_[i_] <- min(trueage[i_], (cp_1_tr + cp_1_id_tr[id[i_]]))
    X_2_[i_] <- min(trueage[i_], MAXX) - (cp_1_tr + cp_1_id_tr[id[i_]])
    trueage[i_] ~ dunif(MINX,MAXX) #dnorm(0, 1^(-2))
    age_tr[i_] ~  dnorm(trueage[i_], 1 / ageerror_tr[i_]^2)

    # Fitted value
    y_[i_] =

      # Segment 1: y ~ 1 + x
      (trueage[i_] >= MINX) * int_1 +

      # Segment 2: y ~ 1 + (1 | id) ~ 0 + x
      (trueage[i_]>= (cp_1_tr + cp_1_id_tr[id[i_]])) * x_2_tr * X_2_[i_]

    # Fitted standard deviation
    tau_y_[i_] = (proxyerror[i_]^2 + (sigma_1)^2)^(-1)

    # Likelihood
    y[i_] ~  dnorm(y_[i_], tau_y_[i_])
  }
  # Transform to original scale:
  cp_1 <- cp_1_tr * 1000
  cp_1_id <- cp_1_id_tr * 1000
  cp_1_sd <- cp_1_sigma_tr * 1000
  x_2 <- x_2_tr / 1000
}
  "


writeLines(modelString, con="TEMPmodel.txt")
parameters <- c("cp_1", "cp_1_id", "cp_1_sd", "int_1", "sigma_1", "x_2")

# run the model
runJagsOut_f14c <- run.jags(method = "parallel",
                       model = "TEMPmodel.txt",
                       monitor = parameters,
                       data = dataList_forjags,
                       n.chains = nChains,
                       adapt = adaptNO,
                       burnin = burninNO,
                       sample = sampleNO,
                       thin = thinstepsNO,
                       summarise = FALSE,
                       plots = FALSE,
                       modules = 'glm')
# Out:
# Adding missing grouping variables: `proxyname`
# Warning message:
# “No initial values were provided - JAGS will use the same initial values for all chains”
# Warning message:
# “You attempted to start parallel chains without setting different PRNG for each chain, which is not recommended.  Different .RNG.name values have been added to each set of initial values.”
# Calling 2 simulations using the parallel method...
# Following the progress of chain 1 (the program will wait for all chains
# to finish before continuing):
# Welcome to JAGS 4.3.2 on Wed Sep  9 08:21:55 2026
# JAGS is free software and comes with ABSOLUTELY NO WARRANTY
# Loading module: basemod: ok
# Loading module: bugs: ok
# . Loading module: glm: ok
# . . Reading data file data.txt
# . Compiling data graph
#    Resolving undeclared variables
#    Allocating nodes
#    Initializing
#    Reading data back into data table
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 170
#    Unobserved stochastic nodes: 99
#    Total graph size: 1631
# . Reading parameter file inits1.txt
# . Reading parameter file inits3.txt
# . Initializing model
# . Adapting 20000
# -------------------------------------------------| 20000
# ++++++++++++++++++++++++++++++++++++++++++++++++++ 100%
# Adaptation successful
# . Updating 20000
# -------------------------------------------------| 20000
# ************************************************** 100%
# . . . . . . . Updating 40000
# -------------------------------------------------| 40000
# ************************************************** 100%
# . . . . . Updating 0
# . Deleting model
# .
# All chains have finished
# Simulation complete.  Reading coda files...
# Coda files loaded successfully
# Finished running the simulation

# %%
# Save the JAGS posterior and the data needed for the plotting section
codaSamples <- coda::as.mcmc.list(runJagsOut_f14c)

dir.create("results", showWarnings = FALSE, recursive = TRUE)

# Keep the original model object as a standalone file
save(
  runJagsOut_f14c,
  file = file.path("results", "anthropocene_cp_f14c_MCMC.RData")
)

# Save exactly the objects required to reproduce the plots.
# No `fit` or `fit2` objects are used by the final JAGS model.
objects_to_save <- c(
  "runJagsOut_f14c",
  "filtered_datatouse_selected_for_jags"
)

# This object contains the original proxy names and is useful for facet labels.
if (exists("filtered_f14cdatatouse", inherits = TRUE)) {
  objects_to_save <- c(objects_to_save, "filtered_f14cdatatouse")
}

save(
  list = objects_to_save,
  file = file.path("results", "f14c_plot_objects.RData")
)

# Save posterior summaries in portable files
mcmc_summary <- summary(codaSamples)

utils::write.csv(
  as.data.frame(mcmc_summary$statistics),
  file.path("results", "summary_f14c_statistics.csv"),
  row.names = TRUE
)

utils::write.csv(
  as.data.frame(mcmc_summary$quantiles),
  file.path("results", "summary_f14c_quantiles.csv"),
  row.names = TRUE
)

capture.output(
  summary(runJagsOut_f14c),
  file = file.path("results", "summary_f14c_runjags.txt")
)

# %% [markdown]
# # Plotting the results

# %%
# Helper functions

# JAGS-native plotting helpers for the F14C changepoint analysis
#
# Exact parameterization used in the JAGS model above:
#   int_1       : plateau/intercept
#   x_2         : post-changepoint slope, transformed to per-year units
#   cp_1        : population changepoint in CE years
#   cp_1_id[k]  : zero-centred dataset-specific offset in years
#
# Therefore the absolute changepoint for dataset k is:
#   cp_1 + cp_1_id[k]

resolve_plot_font <- function(preferred = "LM Sans 10") {
  if (requireNamespace("extrafont", quietly = TRUE)) {
    suppressWarnings(try(extrafont::loadfonts(quiet = TRUE), silent = TRUE))
    available <- suppressWarnings(try(extrafont::fonts(), silent = TRUE))
    if (!inherits(available, "try-error") && preferred %in% available) {
      return(preferred)
    }
  }
  "sans"
}

get_jags_mcmc <- function(x) {
  out <- suppressWarnings(try(coda::as.mcmc.list(x), silent = TRUE))
  if (!inherits(out, "try-error") && coda::is.mcmc.list(out)) {
    return(out)
  }

  if (!is.null(x$mcmc) && coda::is.mcmc.list(x$mcmc)) {
    return(x$mcmc)
  }

  stop("Could not convert `runJagsOut_f14c` to a coda::mcmc.list.", call. = FALSE)
}

posterior_matrix <- function(mcmc) {
  do.call(rbind, lapply(mcmc, as.matrix))
}

indexed_parameter_names <- function(draws, base) {
  pattern <- paste0("^", base, "\\[[0-9]+\\]$")
  nms <- grep(pattern, colnames(draws), value = TRUE)

  if (!length(nms)) {
    return(character(0))
  }

  idx <- as.integer(sub(
    paste0("^", base, "\\[([0-9]+)\\]$"),
    "\\1",
    nms
  ))
  nms[order(idx)]
}

piecewise_mean <- function(x, intercept, slope, cp) {
  intercept + ifelse(x >= cp, slope * (x - cp), 0)
}

sample_draw_indices <- function(n_draws, n = 25, seed = 1234) {
  set.seed(seed)
  sample(seq_len(n_draws), size = min(n, n_draws), replace = FALSE)
}

make_site_lookup <- function(dat) {
  site_ids <- sort(unique(as.integer(dat$id)))

  # `proxyname` is retained by dplyr in the notebook because the source tibble
  # is grouped by proxyname. Use it when available.
  if ("proxyname" %in% names(dat)) {
    lookup <- unique(data.frame(
      id = as.integer(dat$id),
      site = as.character(dat$proxyname),
      stringsAsFactors = FALSE
    ))
    lookup <- lookup[order(lookup$id), , drop = FALSE]
    lookup <- lookup[!duplicated(lookup$id), , drop = FALSE]
    return(lookup)
  }

  # Fallback to the pre-selection tibble if it exists in the notebook session.
  if (exists("filtered_f14cdatatouse", inherits = TRUE)) {
    raw <- get("filtered_f14cdatatouse", inherits = TRUE)
    if (all(c("id_column", "proxyname") %in% names(raw))) {
      lookup <- unique(data.frame(
        id = as.integer(raw$id_column),
        site = as.character(raw$proxyname),
        stringsAsFactors = FALSE
      ))
      lookup <- lookup[order(lookup$id), , drop = FALSE]
      lookup <- lookup[!duplicated(lookup$id), , drop = FALSE]
      return(lookup)
    }
  }

  data.frame(
    id = site_ids,
    site = paste("Site", site_ids),
    stringsAsFactors = FALSE
  )
}

make_error_data <- function(dat, site_lookup) {
  out <- data.frame(
    x = as.numeric(dat$age),
    x_err = as.numeric(dat$ageerror),
    y = as.numeric(dat$y),
    y_err = as.numeric(dat$proxyerror),
    id = as.integer(dat$id)
  )
  out$site <- site_lookup$site[match(out$id, site_lookup$id)]
  out$site <- factor(out$site, levels = site_lookup$site)
  out
}

make_population_lines <- function(draws, x_grid, draw_idx) {
  do.call(rbind, lapply(seq_along(draw_idx), function(j) {
    i <- draw_idx[j]
    data.frame(
      x = x_grid,
      y = piecewise_mean(
        x_grid,
        intercept = draws[i, "int_1"],
        slope = draws[i, "x_2"],
        cp = draws[i, "cp_1"]
      ),
      draw = j
    )
  }))
}

make_site_lines <- function(draws, site_cp_draws, x_grid, draw_idx, site_lookup) {
  do.call(rbind, lapply(seq_along(draw_idx), function(j) {
    i <- draw_idx[j]

    do.call(rbind, lapply(seq_len(nrow(site_lookup)), function(k) {
      data.frame(
        x = x_grid,
        y = piecewise_mean(
          x_grid,
          intercept = draws[i, "int_1"],
          slope = draws[i, "x_2"],
          cp = site_cp_draws[i, k]
        ),
        draw = j,
        site = site_lookup$site[k],
        stringsAsFactors = FALSE
      )
    }))
  }))
}

base_eiv_plot <- function(error_data, family = "sans", facet = FALSE,
                          reference_year = 1952, axis_text_size = 11) {
  p <- ggplot2::ggplot() +
    ggplot2::geom_rect(
      data = error_data,
      ggplot2::aes(
        xmin = x - x_err,
        xmax = x + x_err,
        ymin = y - y_err,
        ymax = y + y_err
      ),
      fill = "cyan",
      alpha = 0.30,
      colour = NA
    ) +
    ggplot2::geom_vline(
      xintercept = reference_year,
      linetype = "dashed",
      colour = "purple"
    ) +
    ggplot2::geom_point(
      data = error_data,
      ggplot2::aes(x = x, y = y),
      alpha = 0.65,
      size = 1.6
    ) +
    ggplot2::labs(
      x = "year (CE)",
      y = expression("F"^14~"C (standardized)")
    ) +
    ggplot2::theme_bw() +
    ggplot2::theme(
      text = ggplot2::element_text(size = 11, family = family),
      axis.text = ggplot2::element_text(size = axis_text_size, family = family),
      axis.title = ggplot2::element_text(family = family),
      legend.position = "none"
    )

  if (facet) {
    p <- p +
      ggplot2::facet_wrap(~site) +
      ggplot2::theme(strip.text = ggplot2::element_text(family = family))
  }

  p
}

plot_population_fit <- function(error_data, line_draws, family = "sans") {
  base_eiv_plot(error_data, family = family, facet = FALSE, axis_text_size = 12) +
    ggplot2::geom_line(
      data = line_draws,
      ggplot2::aes(x = x, y = y, group = draw),
      colour = grDevices::rgb(0.5, 0.5, 0.5, 0.40),
      linewidth = 0.45
    )
}

plot_site_fits <- function(error_data, line_draws, family = "sans") {
  line_draws$site <- factor(
    line_draws$site,
    levels = levels(error_data$site)
  )

  base_eiv_plot(error_data, family = family, facet = TRUE, axis_text_size = 9) +
    ggplot2::geom_line(
      data = line_draws,
      ggplot2::aes(x = x, y = y, group = draw),
      colour = grDevices::rgb(0.5, 0.5, 0.5, 0.40),
      linewidth = 0.40
    )
}

plot_cp_posterior <- function(values, family = "sans", prob = 0.95,
                              comparison_value = 1952) {
  h <- HDInterval::hdi(values, credMass = prob)
  med <- stats::median(values)
  dens <- stats::density(values)

  ggplot2::ggplot(data.frame(value = values), ggplot2::aes(x = value)) +
    ggplot2::geom_density(fill = "grey80", alpha = 0.65, linewidth = 0.6) +
    ggplot2::geom_vline(
      xintercept = comparison_value,
      linetype = "dashed",
      colour = "purple"
    ) +
    ggplot2::geom_vline(xintercept = med, linewidth = 0.6) +
    ggplot2::geom_segment(
      x = unname(h[1]), xend = unname(h[2]),
      y = 0, yend = 0,
      linewidth = 3.2
    ) +
    ggplot2::annotate(
      "text",
      x = med,
      y = max(dens$y) * 0.95,
      label = sprintf(
        "median = %.1f\n95%% HDI: %.1f–%.1f",
        med, unname(h[1]), unname(h[2])
      ),
      vjust = 1,
      family = family,
      size = 3.5
    ) +
    ggplot2::labs(x = "year (CE)", y = "Posterior density") +
    ggplot2::theme_bw() +
    ggplot2::theme(text = ggplot2::element_text(size = 11, family = family))
}

make_absolute_site_cp_mcmc <- function(mcmc, cp_site_names, site_labels) {
  chains <- lapply(mcmc, function(chain) {
    mat <- as.matrix(chain)

    absolute_cp <- sweep(
      mat[, cp_site_names, drop = FALSE],
      1,
      mat[, "cp_1"],
      FUN = "+"
    )

    colnames(absolute_cp) <- site_labels
    coda::mcmc(
      absolute_cp,
      start = stats::start(chain),
      thin = coda::thin(chain)
    )
  })

  coda::mcmc.list(chains)
}

summarise_change_points <- function(pop_cp, site_cp_draws, site_labels,
                                    prob = 0.95) {
  rows <- lapply(seq_len(ncol(site_cp_draws)), function(k) {
    h <- HDInterval::hdi(site_cp_draws[, k], credMass = prob)
    data.frame(
      id = site_labels[k],
      hdi_lower = unname(h[1]),
      median = stats::median(site_cp_draws[, k]),
      hdi_upper = unname(h[2]),
      stringsAsFactors = FALSE
    )
  })

  h_pop <- HDInterval::hdi(pop_cp, credMass = prob)

  rbind(
    do.call(rbind, rows),
    data.frame(
      id = "Population",
      hdi_lower = unname(h_pop[1]),
      median = stats::median(pop_cp),
      hdi_upper = unname(h_pop[2]),
      stringsAsFactors = FALSE
    )
  )
}


# Plotting workflow

# Plot the F14C JAGS results
# ============================================================================
# This cell uses exactly the parameter names monitored by the JAGS model:
#   cp_1, cp_1_id[k], int_1, x_2
# ============================================================================

required_packages <- c("coda", "HDInterval", "ggplot2", "bayesplot", "patchwork")
missing_packages <- required_packages[
  !vapply(required_packages, requireNamespace, logical(1), quietly = TRUE)
]
if (length(missing_packages)) {
  stop(
    "Install the following packages before plotting: ",
    paste(missing_packages, collapse = ", "),
    call. = FALSE
  )
}

dir.create("figures", showWarnings = FALSE, recursive = TRUE)
dir.create("results", showWarnings = FALSE, recursive = TRUE)

# If this cell is run in a fresh R session, load the objects saved above.
plot_objects <- file.path("results", "f14c_plot_objects.RData")
if (
  (!exists("runJagsOut_f14c", inherits = TRUE) ||
   !exists("filtered_datatouse_selected_for_jags", inherits = TRUE)) &&
  file.exists(plot_objects)
) {
  load(plot_objects)
}

required_objects <- c(
  "runJagsOut_f14c",
  "filtered_datatouse_selected_for_jags"
)
missing_objects <- required_objects[
  !vapply(required_objects, exists, logical(1), inherits = TRUE)
]
if (length(missing_objects)) {
  stop(
    "Missing notebook object(s): ",
    paste(missing_objects, collapse = ", "),
    ". Run the JAGS model cell first, or load results/f14c_plot_objects.RData.",
    call. = FALSE
  )
}

# Posterior draws
mcmc <- get_jags_mcmc(runJagsOut_f14c)
draws <- posterior_matrix(mcmc)

# These names come directly from `parameters <- ...` in the JAGS cell.
required_scalar_parameters <- c("cp_1", "int_1", "x_2")
missing_parameters <- setdiff(required_scalar_parameters, colnames(draws))
if (length(missing_parameters)) {
  stop(
    "The JAGS posterior is missing: ",
    paste(missing_parameters, collapse = ", "),
    "\nAvailable parameters: ",
    paste(colnames(draws), collapse = ", "),
    call. = FALSE
  )
}

cp_site_names <- indexed_parameter_names(draws, "cp_1_id")
if (!length(cp_site_names)) {
  stop(
    "No `cp_1_id[k]` parameters were found in the JAGS posterior.\n",
    "Available parameters: ",
    paste(colnames(draws), collapse = ", "),
    call. = FALSE
  )
}

# Plotting data
plot_dat <- as.data.frame(filtered_datatouse_selected_for_jags)
required_columns <- c("age", "ageerror", "y", "proxyerror", "id")
missing_columns <- setdiff(required_columns, names(plot_dat))
if (length(missing_columns)) {
  stop(
    "The plotting data are missing: ",
    paste(missing_columns, collapse = ", "),
    call. = FALSE
  )
}

site_lookup <- make_site_lookup(plot_dat)
n_sites <- nrow(site_lookup)

if (length(cp_site_names) != n_sites) {
  stop(
    "The posterior contains ", length(cp_site_names),
    " `cp_1_id[k]` parameters but the plotting data contain ",
    n_sites, " datasets.\n",
    "Posterior names: ", paste(cp_site_names, collapse = ", "),
    call. = FALSE
  )
}

# `cp_1_id[k]` is already zero-centred inside the JAGS model:
# cp_1_id_tr <- cp_1_id_tr_uncentered - mean(cp_1_id_tr_uncentered)
# and is transformed to years before monitoring.
# Hence absolute site CP = cp_1 + cp_1_id[k].
site_cp_offsets <- draws[, cp_site_names, drop = FALSE]
site_cp_draws <- sweep(
  site_cp_offsets,
  1,
  draws[, "cp_1"],
  FUN = "+"
)
colnames(site_cp_draws) <- site_lookup$site

error_data <- make_error_data(plot_dat, site_lookup)

# Posterior trajectories
x_grid <- seq(
  min(error_data$x - error_data$x_err, na.rm = TRUE),
  max(error_data$x + error_data$x_err, na.rm = TRUE),
  length.out = 250
)

N_POSTERIOR_LINES <- 25
PLOT_SEED <- 1234
REFERENCE_YEAR <- 1952
HDI_PROB <- 0.95

draw_idx <- sample_draw_indices(
  n_draws = nrow(draws),
  n = N_POSTERIOR_LINES,
  seed = PLOT_SEED
)

population_lines <- make_population_lines(draws, x_grid, draw_idx)
site_lines <- make_site_lines(
  draws, site_cp_draws, x_grid, draw_idx, site_lookup
)

plot_family <- resolve_plot_font("LM Sans 10")
message("Plot font: ", plot_family)

# 1. Population-level fit
p_population <- plot_population_fit(
  error_data,
  population_lines,
  family = plot_family
)

# 2. Dataset-level fits
p_sites <- plot_site_fits(
  error_data,
  site_lines,
  family = plot_family
)

# 3. Population changepoint posterior
population_cp_values <- draws[, "cp_1"]
p_cp <- plot_cp_posterior(
  population_cp_values,
  family = plot_family,
  prob = HDI_PROB,
  comparison_value = REFERENCE_YEAR
)

# Display plots in the notebook
print(p_population)
print(p_sites)
print(p_cp)

# Save plots
ggplot2::ggsave(
  file.path("figures", "f14c_population_fit.pdf"),
  p_population,
  width = 7.0, height = 4.8, units = "in"
)

ggplot2::ggsave(
  file.path("figures", "f14c_site_fits.pdf"),
  p_sites,
  width = 9.0, height = 7.0, units = "in"
)

ggplot2::ggsave(
  file.path("figures", "f14c_population_cp_posterior.pdf"),
  p_cp,
  width = 6.5, height = 4.5, units = "in"
)

# Combined figure
p_combined <- patchwork::wrap_plots(
  p_sites,
  patchwork::wrap_plots(p_population, p_cp, ncol = 2),
  ncol = 1,
  heights = c(1.6, 1.0)
) +
  patchwork::plot_annotation(tag_levels = "a")

print(p_combined)

ggplot2::ggsave(
  file.path("figures", "f14c_figure_combined.pdf"),
  p_combined,
  width = 11.0, height = 10.0, units = "in"
)

# Population changepoint diagnostics
p_cp_trace <- bayesplot::mcmc_trace(
  mcmc,
  pars = "cp_1",
  facet_args = list(ncol = 1)
) +
  ggplot2::theme(text = ggplot2::element_text(family = plot_family))

print(p_cp_trace)

ggplot2::ggsave(
  file.path("figures", "f14c_population_cp_trace.pdf"),
  p_cp_trace,
  width = 8.0, height = 4.5, units = "in"
)

p_cp_acf <- bayesplot::mcmc_acf(
  mcmc,
  pars = "cp_1"
) +
  ggplot2::theme(text = ggplot2::element_text(family = plot_family))

print(p_cp_acf)

ggplot2::ggsave(
  file.path("figures", "f14c_population_cp_acf.pdf"),
  p_cp_acf,
  width = 8.0, height = 4.5, units = "in"
)

capture.output(
  coda::gelman.diag(mcmc[, "cp_1"]),
  file = file.path("results", "f14c_population_cp_gelman.txt")
)

# Dataset-level absolute changepoint diagnostics
site_cp_mcmc <- make_absolute_site_cp_mcmc(
  mcmc,
  cp_site_names = cp_site_names,
  site_labels = site_lookup$site
)

p_site_cp_trace <- bayesplot::mcmc_trace(
  site_cp_mcmc,
  facet_args = list(ncol = 3)
) +
  ggplot2::theme(
    text = ggplot2::element_text(family = plot_family),
    strip.text = ggplot2::element_text(family = plot_family)
  )

print(p_site_cp_trace)

ggplot2::ggsave(
  file.path("figures", "f14c_site_cp_trace.pdf"),
  p_site_cp_trace,
  width = 10.0, height = 7.0, units = "in"
)

p_site_cp_density <- bayesplot::mcmc_dens_overlay(
  site_cp_mcmc,
  facet_args = list(ncol = 2)
) +
  ggplot2::theme(
    text = ggplot2::element_text(family = plot_family),
    strip.text = ggplot2::element_text(family = plot_family)
  )

print(p_site_cp_density)

ggplot2::ggsave(
  file.path("figures", "f14c_site_cp_densities.pdf"),
  p_site_cp_density,
  width = 8.0, height = 7.0, units = "in"
)

# HDI summary table
hdi_df <- summarise_change_points(
  pop_cp = population_cp_values,
  site_cp_draws = site_cp_draws,
  site_labels = site_lookup$site,
  prob = HDI_PROB
)

print(hdi_df)

utils::write.csv(
  hdi_df,
  file.path("results", "f14c_change_point_hdi.csv"),
  row.names = FALSE
)

capture.output(
  sessionInfo(),
  file = file.path("results", "sessionInfo_plotting.txt")
)

message("F14C plots and summaries written to figures/ and results/.")
# Out:
# Plot font: sans
# plot without title
# plot without title
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “for '95% HDI: 1958.0–1961.4' in 'mbcsToSbcs': - substituted for – (U+2013)”
# plot without title
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# “for '95% HDI: 1958.0–1961.4' in 'mbcsToSbcs': - substituted for – (U+2013)”
# plot without title
# plot without title
# plot without title
# plot without title
#                             id hdi_lower   median hdi_upper
# 1      1.kaiser_F14C_EMB201/74  1956.418 1960.833  1966.532
# 2         2.kuwae_F14C_BG19S11  1959.330 1960.970  1962.522
# 3    4.mccarthy_F14C_CRA191FRA  1957.538 1961.373  1964.622
# 4   6.zinke_F14C_FLI01A_FL105A  1958.966 1960.416  1961.896
# 5        7.delong_F14C_05WFGB3  1956.865 1958.148  1959.401
# 6 9.fialkiewiczKoziel_F14C_Sn0  1953.872 1956.401  1959.433
# 7                   Population  1957.980 1959.740  1961.400
# F14C plots and summaries written to figures/ and results/.
# plot without title
